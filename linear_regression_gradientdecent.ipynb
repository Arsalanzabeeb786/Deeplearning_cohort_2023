# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/Arsalanzabeeb786/Deeplearning_cohort_2023/blob/main/linear_regression_gradientdecent.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# %% [markdown]
# #Using for loops

# %%
start_time = time.time()
Y = [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750,
4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500]
Y_pred = 9
j = sum(map(lambda x : x**2 ,list((Y_pred-y) for y in Y)))
print(j)
end_time = time.time()
# Calculate and print the time taken
elapsed_time = end_time - start_time
print("Time taken:", elapsed_time, "seconds")
# Out:
# 588847430
# Time taken: 0.0010020732879638672 seconds

# %% [markdown]
# #Using Numpy Arrays

# %%
start_time = time.time()
Ynumpy = np.array([250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750,
                  4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500])
Y_pred = 9
j = np.sum(np.square(Y_pred - Ynumpy))
print(j)
end_time = time.time()
# Calculate and print the time taken
elapsed_time = end_time - start_time
print("Time taken:", elapsed_time, "seconds")
# Out:
# 588847430
# Time taken: 0.0030012130737304688 seconds

# %%
# Sample data for demonstration
X = [1, 2, 3, 4, 5]
Y = [2, 4, 5, 4, 5]

w = 0
b = 0

L = 0.001  # The learning Rate
epochs = 1500 # The number of iterations to perform gradient descent

m = float(len(X)) # Number of elements in X

# Performing Gradient Descent
for i in range(epochs):
    Y_pred = sum(w * x + b for x in X)  # The current predicted value of Y
    j = sum(map(lambda x : x**2 ,list((Y_pred-y) for y in Y)))
    print(j)
    D_w = sum(x * (Y_pred - y) for x, y in zip(X, Y))  # Derivative wrt w
    D_w = D_w / m
    D_b = sum(Y_pred - y for y in Y)  # Derivative wrt b
    D_b = D_b / m

    # Check for NaN or inf values in derivatives
    if D_w != D_w or D_b != D_b or D_w == float('inf') or D_b == float('inf'):
        print("NaN or inf value encountered. Adjust learning rate.")
        break

    w = w - (L * D_w)  # Update w
    b = b - (L * D_b)  # Update b


print(w, b)

# Plotting the data points and regression line
plt.scatter(X, Y, color='blue', label='Data Points')
plt.plot(X, [w * x + b for x in X], color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.show()
# Out:
# 86
# 77.51762
# 69.89955005
# 63.059656020125004
# 56.92029505316282
# 51.411483005729444
# 46.47014329690832
# 42.039429215485384
# 38.06811251249991
# 34.510031805779285
# 31.323594954801525
# 28.471330134289815
# 25.91948084939892
# 23.63764059962476
# 21.598423317551486
# 19.77716608666084
# 18.151660983653507
# 16.701913198667285
# 15.409922864671216
# 14.259488278096057
# 13.236028419075469
# 12.326422883904701
# 11.518867526628627
# 10.802744272991735
# 10.168503720073975
# 9.607559270380744
# 9.112191671381908
# 8.675462941792292
# 8.29113876541916
# 7.953618523219824
# 7.657872215263474
# 7.399383597429988
# 7.174098923677533
# 6.978380744266096
# 6.808966264064912
# 6.66292981356511
# 6.537649028976713
# 6.4307743772739725
# 6.340201697681124
# 6.264047463239012
# 6.200626495100914
# 6.148431888379896
# 6.106116931986611
# 6.072478826205486
# 6.046444020983639
# 6.027055015254264
# 6.013458473267677
# 6.004894528024746
# 6.000687154647969
# 6.000235508020143
# ...

# %%
X = np.array([1, 2, 3, 4, 5])
Y = np.array([2, 4, 5, 4, 5])
plt.scatter(X, Y)
plt.show()

# %%
w = 0
b = 0

L = 0.001  # The learning Rate
epochs = 1500 # The number of iterations to perform gradient descent

m = float(len(X)) # Number of elements in X
Y_pred = np.dot(w, X) + b
npstart_time = time.time()
# Performing Gradient Descent
for i in range(epochs):
    Y_pred = np.dot(w, X) + b  # The current predicted value of Y
    j =np.sum(np.square( Y_pred - Y ))
    j = j/(2*m)
    print(f"Cost is {j}")
    D_w = np.dot(X, (Y_pred - Y))  # Derivative wrt w
    D_w = (D_w / m)
    D_b = Y_pred - Y  # Derivative wrt b
    D_b = np.sum(D_b)
    D_b = (D_b / m)

    # Check for NaN or inf values in derivatives
    if np.isnan(D_w) or np.isnan(D_b) or np.isinf(D_w) or np.isinf(D_b):
        print("NaN or inf value encountered. Adjust learning rate.")
        break

    wtemp = w - (L * D_w)  # Update w
    btemp = b - (L * D_b)  # Update b
    w = wtemp
    b = btemp
npend_time = time.time()
print(f"Time spend in seconds is {npend_time - npstart_time}")
print(w, b)

#0.9730923696446394 0.8530181638143008
# Out:
# Cost is 8.6
# Cost is 8.410884719999999
# Cost is 8.226215251827359
# Cost is 8.045887022257343
# Cost is 7.8697979178292385
# Cost is 7.697848226987963
# Cost is 7.529940583586599
# Cost is 7.365979911717861
# Cost is 7.205873371843228
# Cost is 7.049530308189245
# Cost is 6.896862197381128
# Cost is 6.747782598284642
# Cost is 6.602207103027778
# Cost is 6.460053289174492
# Cost is 6.3212406730234125
# Cost is 6.185690664005061
# Cost is 6.053326520151733
# Cost is 5.924073304614799
# Cost is 5.797857843204838
# Cost is 5.674608682930462
# Cost is 5.554256051512432
# Cost is 5.436731817850051
# Cost is 5.321969453417476
# Cost is 5.2099039945680605
# Cost is 5.10047200572537
# Cost is 4.993611543440023
# Cost is 4.8892621212919725
# Cost is 4.787364675618365
# Cost is 4.687861532047545
# Cost is 4.5906963728202355
# Cost is 4.4958142048793945
# Cost is 4.403161328710662
# Cost is 4.312685307915737
# Cost is 4.224334939501439
# Cost is 4.138060224867647
# Cost is 4.0538123414776415
# ...

# %%
# Making predictions
Y_pred = w*X + b

plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()

# %% [markdown]
# # lets use library to build same

# %%
from sklearn.linear_model import LinearRegression

# Sample data for demonstration
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([2, 4, 5, 4, 5])

# Create a LinearRegression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, Y)

# Get the coefficients and intercept
w = model.coef_[0]
b = model.intercept_

print("Final values:", w, b)


# Plotting the data points and regression line
plt.scatter(X, Y, color='blue', label='Data Points')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.show()
# Out:
# Final values: 0.6 2.2
